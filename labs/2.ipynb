# %% [markdown]
# - в файле Лаб.раб.2.pdf используйте таблицу 2
# - в файле Лаб.5-9.pdf стр 28
# - вариант: 5

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
